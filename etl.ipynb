# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('data/song_data')

# %%
filepath = song_files[0]
print(filepath)
# Out:
# /home/workspace/data/song_data/A/A/A/TRAAAAW128F429D538.json

# %%
df = pd.read_json(filepath, lines = True)
df.head()
# Out:
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  ARD7TVE1187B99BFB1              NaN  California - LA               NaN
#
#   artist_name   duration  num_songs             song_id             title  \
# 0      Casual  218.93179          1  SOMZWCG12A8C13C480  I Didn't Mean To
#
#    year
# 0     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[['song_id', 'title', 'artist_id', 'year', 'duration']].values[0].tolist()
song_data
# Out:
# ['SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[['artist_id','artist_name','artist_location','artist_longitude','artist_latitude']].values[0].tolist()
artist_data
# Out:
# ['ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('data/log_data')

# %%
filepath = log_files[0]
print(filepath)
# Out:
# /home/workspace/data/log_data/2018/11/2018-11-30-events.json

# %%
df = pd.read_json(filepath, lines = True)
df.head()
# Out:
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df[df.page == 'NextSong']
df.head()
# Out:
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %%
t = pd.to_datetime(df['ts'] , unit='ms')
t.head()
# Out:
# 0   2018-11-30 00:22:07.796
# 1   2018-11-30 01:08:41.796
# 2   2018-11-30 01:12:48.796
# 3   2018-11-30 01:17:05.796
# 4   2018-11-30 01:20:56.796
# Name: ts, dtype: datetime64[ns]

# %%
time_data = []
for each in t:
    time_data.append([each,each.hour,each.day, each.week, each.month, each.year, each.dayofweek])
column_labels = ('timestamp', 'hour', 'day', 'weekofyear', 'month',' year', 'weekday')

# %%
time_data
# Out:
# [[Timestamp('2018-11-30 00:22:07.796000'), 0, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:08:41.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:12:48.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:17:05.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:20:56.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:24:32.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:28:19.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:32:00.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:38:17.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:39:53.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:44:10.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:48:36.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:50:28.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 01:55:35.796000'), 1, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 02:01:08.796000'), 2, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 02:05:24.796000'), 2, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 02:10:21.796000'), 2, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 02:15:54.796000'), 2, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 02:19:19.796000'), 2, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:06:30.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:10:30.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:13:03.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:15:41.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:21:09.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:29:23.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:32:46.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:37:24.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:39:31.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:44:28.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:49:50.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:55:42.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 03:58:21.796000'), 3, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:00:57.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:04:13.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:06:01.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:09:20.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:12:58.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:13:07.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:17:10.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:20:32.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:21:20.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:23:31.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:24:50.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:26:49.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:27:14.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:31:08.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:32:02.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:36:30.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:42:05.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:46:03.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:51:49.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:56:11.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 04:57:03.796000'), 4, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:03:06.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:06:32.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:11:09.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:12:20.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:15:12.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:16:54.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:19:35.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:20:54.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:23:34.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:24:45.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:28:28.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:29:04.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:31:25.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:31:44.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:32:47.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:36:03.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:36:45.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:39:39.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:40:31.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:43:04.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:43:56.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:46:01.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:48:56.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:50:07.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:54:19.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:57:11.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 05:58:01.796000'), 5, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:01:40.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:04:50.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:04:55.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:07:57.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:10:18.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:12:54.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:13:23.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:14:02.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:16:35.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:18:28.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:21:31.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:26:25.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:30:35.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:33:56.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:37:14.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:40:47.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:44:27.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:48:28.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:52:31.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:54:42.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 06:58:38.796000'), 6, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:02:23.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:08:35.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:15:24.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:18:31.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:22:12.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:24:45.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:28:29.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:29:09.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:31:39.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:36:23.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:38:51.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:42:37.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:47:05.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 07:49:54.796000'), 7, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 08:16:11.796000'), 8, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 08:20:12.796000'), 8, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 08:21:57.796000'), 8, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 08:26:07.796000'), 8, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 08:29:58.796000'), 8, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 08:32:43.796000'), 8, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 08:38:38.796000'), 8, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 08:46:21.796000'), 8, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:12:54.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:18:07.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:22:53.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:27:08.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:30:53.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:35:18.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:38:54.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:42:09.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:46:06.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:49:40.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:54:05.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:56:25.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 10:59:23.796000'), 10, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:00:01.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:06:18.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:09:49.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:10:18.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:13:07.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:16:10.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:20:03.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:23:44.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:28:16.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:32:04.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:37:23.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:41:03.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:46:23.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 11:49:42.796000'), 11, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 12:10:57.796000'), 12, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 12:31:18.796000'), 12, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 12:34:47.796000'), 12, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 12:39:36.796000'), 12, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 12:47:53.796000'), 12, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 12:52:50.796000'), 12, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 12:57:05.796000'), 12, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 12:57:53.796000'), 12, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:01:42.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:05:54.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:10:16.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:13:45.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:17:25.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:20:30.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:20:44.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:27:49.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:31:28.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:34:49.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:38:42.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:41:51.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:43:40.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:45:20.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:48:07.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:48:55.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:52:37.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:52:55.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:56:36.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:57:21.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:57:24.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 13:59:31.796000'), 13, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:00:38.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:01:42.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:01:43.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:03:21.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:04:47.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:06:43.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:07:56.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:10:01.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:11:25.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:12:16.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:15:25.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:16:36.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:19:48.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:21:45.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:24:02.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:27:42.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:28:26.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:31:15.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:33:39.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:33:53.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:36:07.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:37:56.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:38:37.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:41:06.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:42:01.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:42:38.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:42:45.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:43:50.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:45:13.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:46:43.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:47:35.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:49:37.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:51:37.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:52:04.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:53:33.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:55:25.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:57:52.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:59:31.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 14:59:32.796000'), 14, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:01:06.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:02:42.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:05:47.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:05:56.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:06:38.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:09:01.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:10:07.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:11:47.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:12:54.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:13:03.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:14:35.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:15:05.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:16:02.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:17:07.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:18:58.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:21:29.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:22:09.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:22:54.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:24:45.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:25:59.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:27:25.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:28:30.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:32:00.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:33:06.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:37:07.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:42:22.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:46:15.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:50:08.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:51:02.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:53:37.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:54:23.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:57:42.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 15:58:51.796000'), 15, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:00:31.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:03:06.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:06:15.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:07:52.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:09:16.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:12:03.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:13:08.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:15:19.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:17:45.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:18:18.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:20:04.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:21:23.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:21:33.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:25:17.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:27:09.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:31:25.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:34:12.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:35:57.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:38:10.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:39:12.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:41:23.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:43:28.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:45:28.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:49:06.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:51:42.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:55:41.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 16:59:06.796000'), 16, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:03:03.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:07:22.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:11:16.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:16:14.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:19:28.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:19:58.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:22:01.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:24:07.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:25:36.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:28:37.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:30:27.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:31:24.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:34:27.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:35:07.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:39:08.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:39:17.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:42:58.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:44:00.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:45:41.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:47:13.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:48:55.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:49:45.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:53:44.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:54:43.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:57:24.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 17:58:43.796000'), 17, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:03:19.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:04:23.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:08:07.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:10:01.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:13:36.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:14:56.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:16:20.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:19:03.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:19:33.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:21:19.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:21:46.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:24:05.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:26:12.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:28:08.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:29:02.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:31:34.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:32:46.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:35:19.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:36:25.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:39:22.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:40:05.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:44:36.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:47:58.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 18:51:24.796000'), 18, 30, 48, 11, 2018, 4],
#  [Timestamp('2018-11-30 19:54:24.796000'), 19, 30, 48, 11, 2018, 4]]

# %%
time_df = pd.DataFrame(data=time_data, columns=column_labels)
time_df.head()
# Out:
#                 timestamp  hour  day  weekofyear  month   year  weekday
# 0 2018-11-30 00:22:07.796     0   30          48     11   2018        4
# 1 2018-11-30 01:08:41.796     1   30          48     11   2018        4
# 2 2018-11-30 01:12:48.796     1   30          48     11   2018        4
# 3 2018-11-30 01:17:05.796     1   30          48     11   2018        4
# 4 2018-11-30 01:20:56.796     1   30          48     11   2018        4

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():   
    print(i)
    print(row)
    
    cur.execute(time_table_insert, list(row))
    conn.commit()
# Out:
# 0
# timestamp     2018-11-30 00:22:07.796000
# hour                                   0
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 0, dtype: object
# 1
# timestamp     2018-11-30 01:08:41.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 1, dtype: object
# 2
# timestamp     2018-11-30 01:12:48.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 2, dtype: object
# 3
# timestamp     2018-11-30 01:17:05.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 3, dtype: object
# 4
# timestamp     2018-11-30 01:20:56.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 4, dtype: object
# 5
# timestamp     2018-11-30 01:24:32.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 5, dtype: object
# 6
# timestamp     2018-11-30 01:28:19.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 6, dtype: object
# 7
# timestamp     2018-11-30 01:32:00.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 7, dtype: object
# 8
# timestamp     2018-11-30 01:38:17.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 8, dtype: object
# 9
# timestamp     2018-11-30 01:39:53.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 9, dtype: object
# 10
# timestamp     2018-11-30 01:44:10.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 10, dtype: object
# 11
# timestamp     2018-11-30 01:48:36.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 11, dtype: object
# 12
# timestamp     2018-11-30 01:50:28.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 12, dtype: object
# 13
# timestamp     2018-11-30 01:55:35.796000
# hour                                   1
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 13, dtype: object
# 14
# timestamp     2018-11-30 02:01:08.796000
# hour                                   2
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 14, dtype: object
# 15
# timestamp     2018-11-30 02:05:24.796000
# hour                                   2
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 15, dtype: object
# 16
# timestamp     2018-11-30 02:10:21.796000
# hour                                   2
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 16, dtype: object
# 17
# timestamp     2018-11-30 02:15:54.796000
# hour                                   2
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 17, dtype: object
# 18
# timestamp     2018-11-30 02:19:19.796000
# hour                                   2
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 18, dtype: object
# 19
# timestamp     2018-11-30 03:06:30.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 19, dtype: object
# 20
# timestamp     2018-11-30 03:10:30.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 20, dtype: object
# 21
# timestamp     2018-11-30 03:13:03.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 21, dtype: object
# 22
# timestamp     2018-11-30 03:15:41.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 22, dtype: object
# 23
# timestamp     2018-11-30 03:21:09.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 23, dtype: object
# 24
# timestamp     2018-11-30 03:29:23.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 24, dtype: object
# 25
# timestamp     2018-11-30 03:32:46.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 25, dtype: object
# 26
# timestamp     2018-11-30 03:37:24.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 26, dtype: object
# 27
# timestamp     2018-11-30 03:39:31.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 27, dtype: object
# 28
# timestamp     2018-11-30 03:44:28.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 28, dtype: object
# 29
# timestamp     2018-11-30 03:49:50.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 29, dtype: object
# 30
# timestamp     2018-11-30 03:55:42.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 30, dtype: object
# 31
# timestamp     2018-11-30 03:58:21.796000
# hour                                   3
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 31, dtype: object
# 32
# timestamp     2018-11-30 04:00:57.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 32, dtype: object
# 33
# timestamp     2018-11-30 04:04:13.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 33, dtype: object
# 34
# timestamp     2018-11-30 04:06:01.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 34, dtype: object
# 35
# timestamp     2018-11-30 04:09:20.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 35, dtype: object
# 36
# timestamp     2018-11-30 04:12:58.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 36, dtype: object
# 37
# timestamp     2018-11-30 04:13:07.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 37, dtype: object
# 38
# timestamp     2018-11-30 04:17:10.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 38, dtype: object
# 39
# timestamp     2018-11-30 04:20:32.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 39, dtype: object
# 40
# timestamp     2018-11-30 04:21:20.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 40, dtype: object
# 41
# timestamp     2018-11-30 04:23:31.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 41, dtype: object
# 42
# timestamp     2018-11-30 04:24:50.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 42, dtype: object
# 43
# timestamp     2018-11-30 04:26:49.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 43, dtype: object
# 44
# timestamp     2018-11-30 04:27:14.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 44, dtype: object
# 45
# timestamp     2018-11-30 04:31:08.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 45, dtype: object
# 46
# timestamp     2018-11-30 04:32:02.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 46, dtype: object
# 47
# timestamp     2018-11-30 04:36:30.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 47, dtype: object
# 48
# timestamp     2018-11-30 04:42:05.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 48, dtype: object
# 49
# timestamp     2018-11-30 04:46:03.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 49, dtype: object
# 50
# timestamp     2018-11-30 04:51:49.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 50, dtype: object
# 51
# timestamp     2018-11-30 04:56:11.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 51, dtype: object
# 52
# timestamp     2018-11-30 04:57:03.796000
# hour                                   4
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 52, dtype: object
# 53
# timestamp     2018-11-30 05:03:06.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 53, dtype: object
# 54
# timestamp     2018-11-30 05:06:32.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 54, dtype: object
# 55
# timestamp     2018-11-30 05:11:09.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 55, dtype: object
# 56
# timestamp     2018-11-30 05:12:20.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 56, dtype: object
# 57
# timestamp     2018-11-30 05:15:12.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 57, dtype: object
# 58
# timestamp     2018-11-30 05:16:54.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 58, dtype: object
# 59
# timestamp     2018-11-30 05:19:35.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 59, dtype: object
# 60
# timestamp     2018-11-30 05:20:54.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 60, dtype: object
# 61
# timestamp     2018-11-30 05:23:34.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 61, dtype: object
# 62
# timestamp     2018-11-30 05:24:45.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 62, dtype: object
# 63
# timestamp     2018-11-30 05:28:28.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 63, dtype: object
# 64
# timestamp     2018-11-30 05:29:04.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 64, dtype: object
# 65
# timestamp     2018-11-30 05:31:25.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 65, dtype: object
# 66
# timestamp     2018-11-30 05:31:44.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 66, dtype: object
# 67
# timestamp     2018-11-30 05:32:47.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 67, dtype: object
# 68
# timestamp     2018-11-30 05:36:03.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 68, dtype: object
# 69
# timestamp     2018-11-30 05:36:45.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 69, dtype: object
# 70
# timestamp     2018-11-30 05:39:39.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 70, dtype: object
# 71
# timestamp     2018-11-30 05:40:31.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 71, dtype: object
# 72
# timestamp     2018-11-30 05:43:04.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 72, dtype: object
# 73
# timestamp     2018-11-30 05:43:56.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 73, dtype: object
# 74
# timestamp     2018-11-30 05:46:01.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 74, dtype: object
# 75
# timestamp     2018-11-30 05:48:56.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 75, dtype: object
# 76
# timestamp     2018-11-30 05:50:07.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 76, dtype: object
# 77
# timestamp     2018-11-30 05:54:19.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 77, dtype: object
# 78
# timestamp     2018-11-30 05:57:11.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 78, dtype: object
# 79
# timestamp     2018-11-30 05:58:01.796000
# hour                                   5
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 79, dtype: object
# 80
# timestamp     2018-11-30 06:01:40.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 80, dtype: object
# 81
# timestamp     2018-11-30 06:04:50.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 81, dtype: object
# 82
# timestamp     2018-11-30 06:04:55.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 82, dtype: object
# 83
# timestamp     2018-11-30 06:07:57.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 83, dtype: object
# 84
# timestamp     2018-11-30 06:10:18.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 84, dtype: object
# 85
# timestamp     2018-11-30 06:12:54.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 85, dtype: object
# 86
# timestamp     2018-11-30 06:13:23.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 86, dtype: object
# 87
# timestamp     2018-11-30 06:14:02.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 87, dtype: object
# 88
# timestamp     2018-11-30 06:16:35.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 88, dtype: object
# 89
# timestamp     2018-11-30 06:18:28.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 89, dtype: object
# 90
# timestamp     2018-11-30 06:21:31.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 90, dtype: object
# 91
# timestamp     2018-11-30 06:26:25.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 91, dtype: object
# 92
# timestamp     2018-11-30 06:30:35.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 92, dtype: object
# 93
# timestamp     2018-11-30 06:33:56.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 93, dtype: object
# 94
# timestamp     2018-11-30 06:37:14.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 94, dtype: object
# 95
# timestamp     2018-11-30 06:40:47.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 95, dtype: object
# 96
# timestamp     2018-11-30 06:44:27.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 96, dtype: object
# 97
# timestamp     2018-11-30 06:48:28.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 97, dtype: object
# 98
# timestamp     2018-11-30 06:52:31.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 98, dtype: object
# 99
# timestamp     2018-11-30 06:54:42.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 99, dtype: object
# 100
# timestamp     2018-11-30 06:58:38.796000
# hour                                   6
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 100, dtype: object
# 101
# timestamp     2018-11-30 07:02:23.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 101, dtype: object
# 102
# timestamp     2018-11-30 07:08:35.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 102, dtype: object
# 103
# timestamp     2018-11-30 07:15:24.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 103, dtype: object
# 104
# timestamp     2018-11-30 07:18:31.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 104, dtype: object
# 105
# timestamp     2018-11-30 07:22:12.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 105, dtype: object
# 106
# timestamp     2018-11-30 07:24:45.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 106, dtype: object
# 107
# timestamp     2018-11-30 07:28:29.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 107, dtype: object
# 108
# timestamp     2018-11-30 07:29:09.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 108, dtype: object
# 109
# timestamp     2018-11-30 07:31:39.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 109, dtype: object
# 110
# timestamp     2018-11-30 07:36:23.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 110, dtype: object
# 111
# timestamp     2018-11-30 07:38:51.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 111, dtype: object
# 112
# timestamp     2018-11-30 07:42:37.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 112, dtype: object
# 113
# timestamp     2018-11-30 07:47:05.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 113, dtype: object
# 114
# timestamp     2018-11-30 07:49:54.796000
# hour                                   7
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 114, dtype: object
# 115
# timestamp     2018-11-30 08:16:11.796000
# hour                                   8
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 115, dtype: object
# 116
# timestamp     2018-11-30 08:20:12.796000
# hour                                   8
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 116, dtype: object
# 117
# timestamp     2018-11-30 08:21:57.796000
# hour                                   8
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 117, dtype: object
# 118
# timestamp     2018-11-30 08:26:07.796000
# hour                                   8
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 118, dtype: object
# 119
# timestamp     2018-11-30 08:29:58.796000
# hour                                   8
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 119, dtype: object
# 120
# timestamp     2018-11-30 08:32:43.796000
# hour                                   8
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 120, dtype: object
# 121
# timestamp     2018-11-30 08:38:38.796000
# hour                                   8
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 121, dtype: object
# 122
# timestamp     2018-11-30 08:46:21.796000
# hour                                   8
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 122, dtype: object
# 123
# timestamp     2018-11-30 10:12:54.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 123, dtype: object
# 124
# timestamp     2018-11-30 10:18:07.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 124, dtype: object
# 125
# timestamp     2018-11-30 10:22:53.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 125, dtype: object
# 126
# timestamp     2018-11-30 10:27:08.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 126, dtype: object
# 127
# timestamp     2018-11-30 10:30:53.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 127, dtype: object
# 128
# timestamp     2018-11-30 10:35:18.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 128, dtype: object
# 129
# timestamp     2018-11-30 10:38:54.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 129, dtype: object
# 130
# timestamp     2018-11-30 10:42:09.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 130, dtype: object
# 131
# timestamp     2018-11-30 10:46:06.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 131, dtype: object
# 132
# timestamp     2018-11-30 10:49:40.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 132, dtype: object
# 133
# timestamp     2018-11-30 10:54:05.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 133, dtype: object
# 134
# timestamp     2018-11-30 10:56:25.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 134, dtype: object
# 135
# timestamp     2018-11-30 10:59:23.796000
# hour                                  10
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 135, dtype: object
# 136
# timestamp     2018-11-30 11:00:01.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 136, dtype: object
# 137
# timestamp     2018-11-30 11:06:18.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 137, dtype: object
# 138
# timestamp     2018-11-30 11:09:49.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 138, dtype: object
# 139
# timestamp     2018-11-30 11:10:18.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 139, dtype: object
# 140
# timestamp     2018-11-30 11:13:07.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 140, dtype: object
# 141
# timestamp     2018-11-30 11:16:10.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 141, dtype: object
# 142
# timestamp     2018-11-30 11:20:03.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 142, dtype: object
# 143
# timestamp     2018-11-30 11:23:44.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 143, dtype: object
# 144
# timestamp     2018-11-30 11:28:16.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 144, dtype: object
# 145
# timestamp     2018-11-30 11:32:04.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 145, dtype: object
# 146
# timestamp     2018-11-30 11:37:23.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 146, dtype: object
# 147
# timestamp     2018-11-30 11:41:03.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 147, dtype: object
# 148
# timestamp     2018-11-30 11:46:23.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 148, dtype: object
# 149
# timestamp     2018-11-30 11:49:42.796000
# hour                                  11
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 149, dtype: object
# 150
# timestamp     2018-11-30 12:10:57.796000
# hour                                  12
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 150, dtype: object
# 151
# timestamp     2018-11-30 12:31:18.796000
# hour                                  12
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 151, dtype: object
# 152
# timestamp     2018-11-30 12:34:47.796000
# hour                                  12
# day                                   30
# weekofyear                            48
# ...
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 279, dtype: object
# 280
# timestamp     2018-11-30 17:07:22.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 280, dtype: object
# 281
# timestamp     2018-11-30 17:11:16.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 281, dtype: object
# 282
# timestamp     2018-11-30 17:16:14.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 282, dtype: object
# 283
# timestamp     2018-11-30 17:19:28.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 283, dtype: object
# 284
# timestamp     2018-11-30 17:19:58.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 284, dtype: object
# 285
# timestamp     2018-11-30 17:22:01.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 285, dtype: object
# 286
# timestamp     2018-11-30 17:24:07.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 286, dtype: object
# 287
# timestamp     2018-11-30 17:25:36.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 287, dtype: object
# 288
# timestamp     2018-11-30 17:28:37.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 288, dtype: object
# 289
# timestamp     2018-11-30 17:30:27.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 289, dtype: object
# 290
# timestamp     2018-11-30 17:31:24.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 290, dtype: object
# 291
# timestamp     2018-11-30 17:34:27.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 291, dtype: object
# 292
# timestamp     2018-11-30 17:35:07.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 292, dtype: object
# 293
# timestamp     2018-11-30 17:39:08.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 293, dtype: object
# 294
# timestamp     2018-11-30 17:39:17.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 294, dtype: object
# 295
# timestamp     2018-11-30 17:42:58.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 295, dtype: object
# 296
# timestamp     2018-11-30 17:44:00.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 296, dtype: object
# 297
# timestamp     2018-11-30 17:45:41.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 297, dtype: object
# 298
# timestamp     2018-11-30 17:47:13.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 298, dtype: object
# 299
# timestamp     2018-11-30 17:48:55.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 299, dtype: object
# 300
# timestamp     2018-11-30 17:49:45.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 300, dtype: object
# 301
# timestamp     2018-11-30 17:53:44.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 301, dtype: object
# 302
# timestamp     2018-11-30 17:54:43.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 302, dtype: object
# 303
# timestamp     2018-11-30 17:57:24.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 303, dtype: object
# 304
# timestamp     2018-11-30 17:58:43.796000
# hour                                  17
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 304, dtype: object
# 305
# timestamp     2018-11-30 18:03:19.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 305, dtype: object
# 306
# timestamp     2018-11-30 18:04:23.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 306, dtype: object
# 307
# timestamp     2018-11-30 18:08:07.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 307, dtype: object
# 308
# timestamp     2018-11-30 18:10:01.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 308, dtype: object
# 309
# timestamp     2018-11-30 18:13:36.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 309, dtype: object
# 310
# timestamp     2018-11-30 18:14:56.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 310, dtype: object
# 311
# timestamp     2018-11-30 18:16:20.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 311, dtype: object
# 312
# timestamp     2018-11-30 18:19:03.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 312, dtype: object
# 313
# timestamp     2018-11-30 18:19:33.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 313, dtype: object
# 314
# timestamp     2018-11-30 18:21:19.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 314, dtype: object
# 315
# timestamp     2018-11-30 18:21:46.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 315, dtype: object
# 316
# timestamp     2018-11-30 18:24:05.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 316, dtype: object
# 317
# timestamp     2018-11-30 18:26:12.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 317, dtype: object
# 318
# timestamp     2018-11-30 18:28:08.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 318, dtype: object
# 319
# timestamp     2018-11-30 18:29:02.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 319, dtype: object
# 320
# timestamp     2018-11-30 18:31:34.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 320, dtype: object
# 321
# timestamp     2018-11-30 18:32:46.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 321, dtype: object
# 322
# timestamp     2018-11-30 18:35:19.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 322, dtype: object
# 323
# timestamp     2018-11-30 18:36:25.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 323, dtype: object
# 324
# timestamp     2018-11-30 18:39:22.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 324, dtype: object
# 325
# timestamp     2018-11-30 18:40:05.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 325, dtype: object
# 326
# timestamp     2018-11-30 18:44:36.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 326, dtype: object
# 327
# timestamp     2018-11-30 18:47:58.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 327, dtype: object
# 328
# timestamp     2018-11-30 18:51:24.796000
# hour                                  18
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 328, dtype: object
# 329
# timestamp     2018-11-30 19:54:24.796000
# hour                                  19
# day                                   30
# weekofyear                            48
# month                                 11
#  year                               2018
# weekday                                4
# Name: 329, dtype: object

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[['userId', 'firstName', 'lastName', 'gender', 'level']]
user_df.head()
# Out:
#   userId firstName lastName gender level
# 0     91    Jayden     Bell      M  free
# 1     73     Jacob    Klein      M  paid
# 2     73     Jacob    Klein      M  paid
# 3     73     Jacob    Klein      M  paid
# 4     73     Jacob    Klein      M  paid

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    print(i)
    print(row)
    cur.execute(user_table_insert, row)
    conn.commit()
# Out:
# 0
# userId           91
# firstName    Jayden
# lastName       Bell
# gender            M
# level          free
# Name: 0, dtype: object
# 1
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 1, dtype: object
# 2
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 2, dtype: object
# 3
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 3, dtype: object
# 4
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 4, dtype: object
# 5
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 5, dtype: object
# 6
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 6, dtype: object
# 7
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 7, dtype: object
# 9
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 9, dtype: object
# 10
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 10, dtype: object
# 11
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 11, dtype: object
# 12
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 12, dtype: object
# 13
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 13, dtype: object
# 14
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 14, dtype: object
# 15
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 15, dtype: object
# 16
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 16, dtype: object
# 17
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 17, dtype: object
# 18
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 18, dtype: object
# 19
# userId          73
# firstName    Jacob
# lastName     Klein
# gender           M
# level         paid
# Name: 19, dtype: object
# 23
# userId          86
# firstName    Aiden
# lastName      Hess
# gender           M
# level         free
# Name: 23, dtype: object
# 24
# userId          86
# firstName    Aiden
# lastName      Hess
# gender           M
# level         free
# Name: 24, dtype: object
# 25
# userId          86
# firstName    Aiden
# lastName      Hess
# gender           M
# level         free
# Name: 25, dtype: object
# 26
# userId          86
# firstName    Aiden
# lastName      Hess
# gender           M
# level         free
# Name: 26, dtype: object
# 27
# userId          86
# firstName    Aiden
# lastName      Hess
# gender           M
# level         free
# Name: 27, dtype: object
# 30
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 30, dtype: object
# 31
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 31, dtype: object
# 33
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 33, dtype: object
# 35
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 35, dtype: object
# 36
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 36, dtype: object
# 38
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 38, dtype: object
# 39
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 39, dtype: object
# 40
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 40, dtype: object
# 41
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 41, dtype: object
# 42
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 42, dtype: object
# 43
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 43, dtype: object
# 44
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 44, dtype: object
# 45
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 45, dtype: object
# 46
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 46, dtype: object
# 48
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 48, dtype: object
# 50
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 50, dtype: object
# 51
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 51, dtype: object
# 52
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 52, dtype: object
# 53
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 53, dtype: object
# 54
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 54, dtype: object
# 55
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 55, dtype: object
# 56
# userId            24
# firstName      Layla
# lastName     Griffin
# gender             F
# level           paid
# Name: 56, dtype: object
# 57
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 57, dtype: object
# 58
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 58, dtype: object
# 59
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 59, dtype: object
# 60
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 60, dtype: object
# 61
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 61, dtype: object
# 62
# userId              57
# firstName    Katherine
# lastName           Gay
# gender               F
# level             free
# Name: 62, dtype: object
# 63
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 63, dtype: object
# 64
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 64, dtype: object
# 65
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 65, dtype: object
# 66
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 66, dtype: object
# 69
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 69, dtype: object
# 70
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 70, dtype: object
# 71
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 71, dtype: object
# 72
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 72, dtype: object
# 73
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 73, dtype: object
# 74
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 74, dtype: object
# 75
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 75, dtype: object
# 76
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 76, dtype: object
# 77
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 77, dtype: object
# 79
# userId          92
# firstName    Ryann
# lastName     Smith
# gender           F
# level         free
# Name: 79, dtype: object
# 80
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 80, dtype: object
# 81
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 81, dtype: object
# 82
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 82, dtype: object
# 83
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 83, dtype: object
# 84
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 84, dtype: object
# 86
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 86, dtype: object
# 87
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 87, dtype: object
# 88
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 88, dtype: object
# 89
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 89, dtype: object
# 90
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 90, dtype: object
# 91
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 91, dtype: object
# 92
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 92, dtype: object
# 93
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 93, dtype: object
# 94
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 94, dtype: object
# 96
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 96, dtype: object
# 97
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 97, dtype: object
# 98
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 98, dtype: object
# 99
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 99, dtype: object
# 100
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 100, dtype: object
# 101
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 101, dtype: object
# 102
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 102, dtype: object
# 103
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 103, dtype: object
# 104
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 104, dtype: object
# 105
# userId            30
# firstName      Avery
# lastName     Watkins
# gender             F
# level           paid
# Name: 105, dtype: object
# 107
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 107, dtype: object
# 108
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 108, dtype: object
# 109
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 109, dtype: object
# 110
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 110, dtype: object
# 111
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 111, dtype: object
# 112
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 112, dtype: object
# 113
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 113, dtype: object
# 114
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 114, dtype: object
# 115
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 115, dtype: object
# 116
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 116, dtype: object
# 117
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 117, dtype: object
# 118
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 118, dtype: object
# 119
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 119, dtype: object
# 120
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 120, dtype: object
# 121
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 121, dtype: object
# 122
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 122, dtype: object
# 123
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 123, dtype: object
# 124
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 124, dtype: object
# 125
# userId           74
# firstName    Braden
# lastName     Parker
# gender            M
# level          free
# Name: 125, dtype: object
# 126
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 126, dtype: object
# 127
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 127, dtype: object
# 128
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 128, dtype: object
# 129
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 129, dtype: object
# 130
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 130, dtype: object
# 131
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 131, dtype: object
# 135
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 135, dtype: object
# 136
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 136, dtype: object
# 137
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 137, dtype: object
# 138
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 138, dtype: object
# 139
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 139, dtype: object
# 140
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 140, dtype: object
# 141
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 141, dtype: object
# 142
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 142, dtype: object
# 146
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 146, dtype: object
# 147
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 147, dtype: object
# 148
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 148, dtype: object
# 149
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 149, dtype: object
# 150
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 150, dtype: object
# 151
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 151, dtype: object
# 152
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 152, dtype: object
# 153
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 153, dtype: object
# 154
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 154, dtype: object
# 155
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 155, dtype: object
# 156
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 156, dtype: object
# 157
# userId          92
# firstName    Ryann
# lastName     Smith
# gender           F
# level         free
# Name: 157, dtype: object
# 158
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 158, dtype: object
# 159
# userId          92
# firstName    Ryann
# lastName     Smith
# gender           F
# level         free
# Name: 159, dtype: object
# 160
# userId          92
# firstName    Ryann
# lastName     Smith
# gender           F
# level         free
# Name: 160, dtype: object
# 161
# userId          92
# firstName    Ryann
# lastName     Smith
# gender           F
# level         free
# Name: 161, dtype: object
# 162
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 162, dtype: object
# 163
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 163, dtype: object
# 164
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 164, dtype: object
# 165
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 165, dtype: object
# 169
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 169, dtype: object
# 170
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 170, dtype: object
# 171
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 171, dtype: object
# 173
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 173, dtype: object
# 174
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 174, dtype: object
# 175
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 175, dtype: object
# 176
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 176, dtype: object
# 177
# userId            12
# firstName     Austin
# lastName     Rosales
# gender             M
# level           free
# Name: 177, dtype: object
# 179
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 179, dtype: object
# 180
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 180, dtype: object
# 181
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 181, dtype: object
# 182
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 182, dtype: object
# 183
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 183, dtype: object
# 185
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 185, dtype: object
# 186
# userId             61
# firstName      Samuel
# lastName     Gonzalez
# gender              M
# level            free
# Name: 186, dtype: object
# 187
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 187, dtype: object
# 189
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 189, dtype: object
# 190
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 190, dtype: object
# 191
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 191, dtype: object
# 192
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 192, dtype: object
# 193
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 193, dtype: object
# 194
# userId           43
# firstName    Jahiem
# lastName      Miles
# gender            M
# level          free
# Name: 194, dtype: object
# 197
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 197, dtype: object
# 198
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 198, dtype: object
# 199
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 199, dtype: object
# 200
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 200, dtype: object
# 201
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 201, dtype: object
# 205
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 205, dtype: object
# 206
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 206, dtype: object
# 207
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 207, dtype: object
# 208
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 208, dtype: object
# 209
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 209, dtype: object
# 210
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 210, dtype: object
# 211
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 211, dtype: object
# 212
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 212, dtype: object
# 213
# userId             50
# firstName         Ava
# lastName     Robinson
# gender              F
# level            free
# Name: 213, dtype: object
# 215
# userId             50
# firstName         Ava
# lastName     Robinson
# gender              F
# level            free
# Name: 215, dtype: object
# 216
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 216, dtype: object
# 217
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 217, dtype: object
# 218
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 218, dtype: object
# 219
# userId             50
# firstName         Ava
# lastName     Robinson
# gender              F
# level            free
# Name: 219, dtype: object
# 220
# userId          26
# firstName     Ryan
# lastName     Smith
# gender           M
# level         free
# Name: 220, dtype: object
# 221
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 221, dtype: object
# 222
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 222, dtype: object
# 223
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 223, dtype: object
# 224
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 224, dtype: object
# 225
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 225, dtype: object
# 226
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 226, dtype: object
# 227
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 227, dtype: object
# 228
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 228, dtype: object
# 229
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 229, dtype: object
# 230
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 230, dtype: object
# 231
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 231, dtype: object
# 232
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 232, dtype: object
# 233
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 233, dtype: object
# 238
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 238, dtype: object
# 239
# userId          101
# firstName    Jayden
# lastName        Fox
# gender            M
# level          free
# Name: 239, dtype: object
# 240
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 240, dtype: object
# 241
# userId          101
# firstName    Jayden
# lastName        Fox
# gender            M
# level          free
# Name: 241, dtype: object
# 242
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 242, dtype: object
# 243
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 243, dtype: object
# 244
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 244, dtype: object
# 245
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 245, dtype: object
# 246
# userId          101
# firstName    Jayden
# lastName        Fox
# gender            M
# level          free
# Name: 246, dtype: object
# 247
# userId          101
# firstName    Jayden
# lastName        Fox
# gender            M
# level          free
# Name: 247, dtype: object
# 248
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 248, dtype: object
# 249
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 249, dtype: object
# 250
# userId          101
# firstName    Jayden
# lastName        Fox
# gender            M
# level          free
# Name: 250, dtype: object
# 251
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 251, dtype: object
# 252
# userId          101
# firstName    Jayden
# lastName        Fox
# gender            M
# level          free
# Name: 252, dtype: object
# 253
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 253, dtype: object
# 254
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 254, dtype: object
# 255
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 255, dtype: object
# 257
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 257, dtype: object
# 260
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 260, dtype: object
# 261
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 261, dtype: object
# 262
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 262, dtype: object
# 263
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 263, dtype: object
# 264
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 264, dtype: object
# 265
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 265, dtype: object
# 266
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 266, dtype: object
# 267
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 267, dtype: object
# 268
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 268, dtype: object
# 269
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 269, dtype: object
# 270
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 270, dtype: object
# 271
# userId              88
# firstName     Mohammad
# lastName     Rodriguez
# gender               M
# level             paid
# Name: 271, dtype: object
# 272
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 272, dtype: object
# 273
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 273, dtype: object
# 274
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 274, dtype: object
# 275
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 275, dtype: object
# 276
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 276, dtype: object
# 277
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 277, dtype: object
# 278
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 278, dtype: object
# 280
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 280, dtype: object
# 281
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 281, dtype: object
# 282
# userId            36
# firstName    Matthew
# lastName       Jones
# gender             M
# level           paid
# Name: 282, dtype: object
# 284
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 284, dtype: object
# 285
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 285, dtype: object
# 286
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 286, dtype: object
# 287
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 287, dtype: object
# 288
# userId            85
# firstName    Kinsley
# lastName       Young
# gender             F
# level           paid
# Name: 288, dtype: object
# 289
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 289, dtype: object
# 290
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 290, dtype: object
# 291
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 291, dtype: object
# 292
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 292, dtype: object
# 293
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 293, dtype: object
# 294
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 294, dtype: object
# 295
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 295, dtype: object
# 296
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 296, dtype: object
# 297
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 297, dtype: object
# 298
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 298, dtype: object
# 299
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 299, dtype: object
# 300
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 300, dtype: object
# 301
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 301, dtype: object
# 302
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 302, dtype: object
# 303
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 303, dtype: object
# 304
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 304, dtype: object
# 305
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 305, dtype: object
# 306
# userId          78
# firstName    Chloe
# lastName      Roth
# gender           F
# level         free
# Name: 306, dtype: object
# 307
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 307, dtype: object
# 308
# userId          78
# firstName    Chloe
# lastName      Roth
# gender           F
# level         free
# Name: 308, dtype: object
# 309
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 309, dtype: object
# 311
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 311, dtype: object
# 312
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 312, dtype: object
# 313
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 313, dtype: object
# 315
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 315, dtype: object
# 317
# userId            33
# firstName    Bronson
# lastName      Harris
# gender             M
# level           free
# Name: 317, dtype: object
# 318
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 318, dtype: object
# 319
# userId            33
# firstName    Bronson
# lastName      Harris
# gender             M
# level           free
# Name: 319, dtype: object
# 322
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 322, dtype: object
# 325
# userId            33
# firstName    Bronson
# lastName      Harris
# gender             M
# level           free
# Name: 325, dtype: object
# 327
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 327, dtype: object
# 329
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 329, dtype: object
# 330
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 330, dtype: object
# 331
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 331, dtype: object
# 333
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 333, dtype: object
# 334
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 334, dtype: object
# 335
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 335, dtype: object
# 336
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 336, dtype: object
# 338
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 338, dtype: object
# 339
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 339, dtype: object
# 340
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 340, dtype: object
# 341
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 341, dtype: object
# 342
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 342, dtype: object
# 343
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 343, dtype: object
# 344
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 344, dtype: object
# 345
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 345, dtype: object
# 346
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 346, dtype: object
# 347
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 347, dtype: object
# 348
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 348, dtype: object
# 349
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 349, dtype: object
# 350
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 350, dtype: object
# 351
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 351, dtype: object
# 352
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 352, dtype: object
# 353
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 353, dtype: object
# 354
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 354, dtype: object
# 355
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 355, dtype: object
# 356
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 356, dtype: object
# 357
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 357, dtype: object
# 358
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 358, dtype: object
# 359
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 359, dtype: object
# 360
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 360, dtype: object
# 361
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 361, dtype: object
# 362
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 362, dtype: object
# 363
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 363, dtype: object
# 364
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 364, dtype: object
# 365
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 365, dtype: object
# 366
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 366, dtype: object
# 367
# userId           91
# firstName    Jayden
# lastName       Bell
# gender            M
# level          free
# Name: 367, dtype: object
# 368
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 368, dtype: object
# 369
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 369, dtype: object
# 370
# userId           91
# firstName    Jayden
# lastName       Bell
# gender            M
# level          free
# Name: 370, dtype: object
# 371
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 371, dtype: object
# 372
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 372, dtype: object
# 373
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 373, dtype: object
# 374
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 374, dtype: object
# 375
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 375, dtype: object
# 376
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 376, dtype: object
# 377
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 377, dtype: object
# 378
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 378, dtype: object
# 380
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 380, dtype: object
# 381
# userId           49
# firstName     Chloe
# lastName     Cuevas
# gender            F
# level          paid
# Name: 381, dtype: object
# 382
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 382, dtype: object
# 383
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 383, dtype: object
# 384
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 384, dtype: object
# 385
# userId           16
# firstName     Rylan
# lastName     George
# gender            M
# level          paid
# Name: 385, dtype: object
# 387
# userId            5
# firstName    Elijah
# lastName      Davis
# gender            M
# level          free
# Name: 387, dtype: object

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = (index, pd.to_datetime(row.ts, unit='ms'), int(row.userId), row.level, songid, artistid, row.sessionId, row.location, row.userAgent)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
